# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
data = pd.read_csv('homeprices.csv')

# %%
data.head()
# Out:
#               town  area   price
# 0  monroe township  2600  550000
# 1  monroe township  3000  565000
# 2  monroe township  3200  610000
# 3  monroe township  3600  680000
# 4  monroe township  4000  725000

# %%
sns.scatterplot(x = 'area', y = 'price', data = data,hue = 'town')
# Out:
# <Axes: xlabel='area', ylabel='price'>

# %%
data
# Out:
#     town  area   price
# 0      0  2600  550000
# 1      0  3000  565000
# 2      0  3200  610000
# 3      0  3600  680000
# 4      0  4000  725000
# 5      2  2600  585000
# 6      2  2800  615000
# 7      2  3300  650000
# 8      2  3600  710000
# 9      1  2600  575000
# 10     1  2900  600000
# 11     1  3100  620000
# 12     1  3600  695000

# %%
from sklearn.preprocessing import LabelEncoder

# %%
x = data.iloc[:,:2]
y = data.price

# %%
la = LabelEncoder()

# %%
data['town'] = la.fit_transform(data['town'])

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(x,y)
# Out:
# LinearRegression()

# %%
lr.score(x,y) *100
# Out:
# 95.52018104317442
