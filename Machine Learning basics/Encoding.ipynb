# %%
import pandas as pd
import sklearn

# %%
df = pd.read_csv('data_science_job.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 df = pd.read_csv('/data_science_job.csv')
#
# File c:\Users\siddh\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
df.isnull().sum()
# Out:
# enrollee_id                  0
# city                         0
# city_development_index     479
# gender                    4508
# relevent_experience          0
# enrolled_university        386
# education_level            460
# major_discipline          2813
# experience                  65
# company_size              5938
# company_type              6140
# training_hours             766
# target                       0
# dtype: int64

# %%
df.fillna(method = 'bfill',inplace = True)
# Out:
# C:\Users\siddh\AppData\Local\Temp\ipykernel_12412\4048859065.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method = 'bfill',inplace = True)

# %%
pd.get_dummies(df['gender']).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19158 entries, 0 to 19157
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Female  19158 non-null  bool
#  1   Male    19158 non-null  bool
#  2   Other   19158 non-null  bool
# dtypes: bool(3)
# memory usage: 56.3 KB

# %%
# df['gender'].value_counts()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19158 entries, 0 to 19157
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   enrollee_id             19158 non-null  int64
#  1   city                    19158 non-null  object
#  2   city_development_index  19158 non-null  float64
#  3   gender                  19157 non-null  object
#  4   relevent_experience     19158 non-null  object
#  5   enrolled_university     19158 non-null  object
#  6   education_level         19158 non-null  object
#  7   major_discipline        19156 non-null  object
#  8   experience              19158 non-null  float64
#  9   company_size            19157 non-null  object
#  10  company_type            19157 non-null  object
#  11  training_hours          19158 non-null  float64
#  12  target                  19158 non-null  float64
# dtypes: float64(4), int64(1), object(8)
# memory usage: 1.9+ MB

# %%
from sklearn.preprocessing import OneHotEncoder

# %% [markdown]
# # oneHot encoding by using pandas

# %%
Data = df[['gender']]
pd.get_dummies(Data).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19158 entries, 0 to 19157
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   gender_Female  19158 non-null  bool
#  1   gender_Male    19158 non-null  bool
#  2   gender_Other   19158 non-null  bool
# dtypes: bool(3)
# memory usage: 56.3 KB

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
ohc = OneHotEncoder(sparse_output=False)
arr = ohc.fit_transform(df[['gender']])

# %%
new_df.drop(['F','None'],axis = 1,inplace = True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 new_df.drop(['F','None'],axis = 1,inplace = True)
#
# NameError: name 'new_df' is not defined

# %%
df['Encoded Gender'] = new_df['Gender']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 df['Encoded Gender'] = new_df['Gender']
#
# NameError: name 'new_df' is not defined

# %%
df.head()
# Out:
#    enrollee_id      city  city_development_index gender  \
# 0         8949  city_103                   0.920   Male
# 1        29725   city_40                   0.776   Male
# 2        11561   city_21                   0.624   Male
# 3        33241  city_115                   0.789   Male
# 4          666  city_162                   0.767   Male
#
#        relevent_experience enrolled_university education_level  \
# 0  Has relevent experience       no_enrollment        Graduate
# 1   No relevent experience       no_enrollment        Graduate
# 2   No relevent experience    Full time course        Graduate
# 3   No relevent experience       no_enrollment        Graduate
# 4  Has relevent experience       no_enrollment         Masters
#
#   major_discipline  experience company_size    company_type  training_hours  \
# 0             STEM        20.0        50-99         Pvt Ltd            36.0
# 1             STEM        15.0        50-99         Pvt Ltd            47.0
# ...

# %%
df['Encoded Gender'].unique()

# %%
df['enrolled_university'].unique()

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()
df['enrolled_university'] = le.fit_transform(df['enrolled_university'])

# %%
df.head()

# %%
df['enrolled_university'].mode()[0]
