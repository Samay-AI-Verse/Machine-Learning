# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('data_science_job.csv')

# %%
df.head()
# Out:
#    enrollee_id      city  city_development_index gender  \
# 0         8949  city_103                   0.920   Male
# 1        29725   city_40                   0.776   Male
# 2        11561   city_21                   0.624    NaN
# 3        33241  city_115                   0.789    NaN
# 4          666  city_162                   0.767   Male
#
#        relevent_experience enrolled_university education_level  \
# 0  Has relevent experience       no_enrollment        Graduate
# 1   No relevent experience       no_enrollment        Graduate
# 2   No relevent experience    Full time course        Graduate
# 3   No relevent experience                 NaN        Graduate
# 4  Has relevent experience       no_enrollment         Masters
#
#   major_discipline  experience company_size    company_type  training_hours  \
# 0             STEM        20.0          NaN             NaN            36.0
# 1             STEM        15.0        50-99         Pvt Ltd            47.0
# ...

# %%
df.isnull().sum()
# Out:
# enrollee_id                  0
# city                         0
# city_development_index     479
# gender                    4508
# relevent_experience          0
# enrolled_university        386
# education_level            460
# major_discipline          2813
# experience                  65
# company_size              5938
# company_type              6140
# training_hours             766
# target                       0
# dtype: int64

# %%
(df.isnull().sum()/df.shape[0])*100
# Out:
# enrollee_id                0.000000
# city                       0.000000
# city_development_index     2.500261
# gender                    23.530640
# relevent_experience        0.000000
# enrolled_university        2.014824
# education_level            2.401086
# major_discipline          14.683161
# experience                 0.339284
# company_size              30.994885
# company_type              32.049274
# training_hours             3.998330
# target                     0.000000
# dtype: float64

# %% [markdown]
# # Checking Total persentages of null values of whole data set

# %%
# df.drop(['company_size','company_type'],axis = 1,inplace = True)

# %%
(df.isnull().sum().sum()/(df.shape[0]*df.shape[1]))*100
# Out:
# 8.654749572381894

# %%
df.shape
# Out:
# (19158, 13)

# %%
df.isnull().sum()
# Out:
# enrollee_id                  0
# city                         0
# city_development_index     479
# gender                    4508
# relevent_experience          0
# enrolled_university        386
# education_level            460
# major_discipline          2813
# experience                  65
# company_size              5938
# company_type              6140
# training_hours             766
# target                       0
# dtype: int64

# %%
df.head()
# Out:
#    enrollee_id      city  city_development_index gender  \
# 0         8949  city_103                   0.920   Male
# 1        29725   city_40                   0.776   Male
# 2        11561   city_21                   0.624    NaN
# 3        33241  city_115                   0.789    NaN
# 4          666  city_162                   0.767   Male
#
#        relevent_experience enrolled_university education_level  \
# 0  Has relevent experience       no_enrollment        Graduate
# 1   No relevent experience       no_enrollment        Graduate
# 2   No relevent experience    Full time course        Graduate
# 3   No relevent experience                 NaN        Graduate
# 4  Has relevent experience       no_enrollment         Masters
#
#   major_discipline  experience company_size    company_type  training_hours  \
# 0             STEM        20.0          NaN             NaN            36.0
# 1             STEM        15.0        50-99         Pvt Ltd            47.0
# ...

# %%
# for x in df.describe(include = 'object'):
#     print(x)
#     print(df[x])
#     print('-'*50)

# %%
# df.info()

# %%
(df.isnull().sum().sum()/df.size)*100
# Out:
# 8.654749572381894

# %%
# sns.kdeplot(df.isnull())

# %% [markdown]
# # Deleting the number of Rows

# %%
# df.drop(index = range(60))

# %%
df.isnull().sum().sum()
# Out:
# 21555

# %%
df.shape[0]*df.shape[1]
# Out:
# 249054

# %%
total_null = (df.isnull().sum().sum()/(df.shape[0]*df.shape[1]))*100

# %%
df.head(2)
# Out:
#    enrollee_id      city  city_development_index gender  \
# 0         8949  city_103                   0.920   Male
# 1        29725   city_40                   0.776   Male
#
#        relevent_experience enrolled_university education_level  \
# 0  Has relevent experience       no_enrollment        Graduate
# 1   No relevent experience       no_enrollment        Graduate
#
#   major_discipline  experience company_size company_type  training_hours  \
# 0             STEM        20.0          NaN          NaN            36.0
# 1             STEM        15.0        50-99      Pvt Ltd            47.0
#
#    target
# 0     1.0
# 1     0.0

# %%
(df.isnull().sum()/df.shape[0])*100
# Out:
# enrollee_id                0.000000
# city                       0.000000
# city_development_index     2.500261
# gender                    23.530640
# relevent_experience        0.000000
# enrolled_university        2.014824
# education_level            2.401086
# major_discipline          14.683161
# experience                 0.339284
# company_size              30.994885
# company_type              32.049274
# training_hours             3.998330
# target                     0.000000
# dtype: float64

# %%
notnullvalues = df.notnull().sum()
nullvalues = df.isnull().sum()

# %%
plt.figure(figsize = (25,6))
plt.bar(df.columns, notnullvalues)
plt.bar(df.columns, nullvalues)
# Out:
# <BarContainer object of 13 artists>

# %%
filled = (df.notnull().sum().sum()/df.size)*100
null = (df.isnull().sum().sum()/ df.size)*100
plt.figure(figsize = (5,4))
plt.bar(['Fill values','Null Values'],[filled,null],edgecolor = 'k')
# Out:
# <BarContainer object of 2 artists>

# %%
df.isnull().sum()
# Out:
# enrollee_id                  0
# city                         0
# city_development_index     479
# gender                    4508
# relevent_experience          0
# enrolled_university        386
# education_level            460
# major_discipline          2813
# experience                  65
# company_size              5938
# company_type              6140
# training_hours             766
# target                       0
# dtype: int64

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
df.drop(['company_size','company_type'],axis = 1,inplace = True)

# %%
# df.dropna(inplace = True)/

# %%
df.isnull().sum()
# Out:
# enrollee_id                  0
# city                         0
# city_development_index     479
# gender                    4508
# relevent_experience          0
# enrolled_university        386
# education_level            460
# major_discipline          2813
# experience                  65
# training_hours             766
# target                       0
# dtype: int64

# %%
df['gender'].fillna(df['gender'].mode()[0])
# Out:
# 0        Male
# 1        Male
# 2        Male
# 3        Male
# 4        Male
#          ...
# 19153    Male
# 19154    Male
# 19155    Male
# 19156    Male
# 19157    Male
# Name: gender, Length: 19158, dtype: object

# %%
for i in df.select_dtypes(include = 'object').columns:
    df[i].fillna(df[i].mode()[0],inplace = True)
# Out:
# C:\Users\siddh\AppData\Local\Temp\ipykernel_9992\51670110.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[i].fillna(df[i].mode()[0],inplace = True)

# %%
df.isnull().sum()
# Out:
# enrollee_id                 0
# city                        0
# city_development_index    479
# gender                      0
# relevent_experience         0
# enrolled_university         0
# education_level             0
# major_discipline            0
# experience                 65
# training_hours            766
# target                      0
# dtype: int64

# %%
# df.fillna(method = 'ffill',inplace = True)

# %%
df.isnull().sum()
# Out:
# enrollee_id                 0
# city                        0
# city_development_index    479
# gender                      0
# relevent_experience         0
# enrolled_university         0
# education_level             0
# major_discipline            0
# experience                 65
# training_hours            766
# target                      0
# dtype: int64

# %%
(df['city_development_index'].isnull().sum()/df['city_development_index'].count())*100
# Out:
# 2.5643771079822257

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19158 entries, 0 to 19157
# Data columns (total 11 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   enrollee_id             19158 non-null  int64
#  1   city                    19158 non-null  object
#  2   city_development_index  18679 non-null  float64
#  3   gender                  19158 non-null  object
#  4   relevent_experience     19158 non-null  object
#  5   enrolled_university     19158 non-null  object
#  6   education_level         19158 non-null  object
#  7   major_discipline        19158 non-null  object
#  8   experience              19093 non-null  float64
#  9   training_hours          18392 non-null  float64
#  10  target                  19158 non-null  float64
# dtypes: float64(4), int64(1), object(6)
# memory usage: 1.6+ MB

# %%
new_data = df.select_dtypes(include = ['int','float64'])

# %%
new_data.columns
# Out:
# Index(['enrollee_id', 'city_development_index', 'experience', 'training_hours',
#        'target'],
#       dtype='object')

# %%
from sklearn.impute import SimpleImputer

# %%
# si = SimpleImputer(strategy = 'mean')
# ar = si.fit_transform(df[['enrollee_id', 'city_development_index', 'experience', 'training_hours',
#        'target']])

# %%
# new_dataset = pd.DataFrame(ar,columns =['enrollee_id', 'city_development_index', 'experience', 'training_hours',
#        'target'] )

# %%
# new_dataset.isnull().sum()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19158 entries, 0 to 19157
# Data columns (total 11 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   enrollee_id             19158 non-null  int64
#  1   city                    19158 non-null  object
#  2   city_development_index  18679 non-null  float64
#  3   gender                  19158 non-null  object
#  4   relevent_experience     19158 non-null  object
#  5   enrolled_university     19158 non-null  object
#  6   education_level         19158 non-null  object
#  7   major_discipline        19158 non-null  object
#  8   experience              19093 non-null  float64
#  9   training_hours          18392 non-null  float64
#  10  target                  19158 non-null  float64
# dtypes: float64(4), int64(1), object(6)
# memory usage: 1.6+ MB

# %%
from sklearn.impute import SimpleImputer

# %%
new_data = df.select_dtypes(include = [int,float])

# %%
new_data.head()
# Out:
#    enrollee_id  city_development_index  experience  training_hours  target
# 0         8949                   0.920        20.0            36.0     1.0
# 1        29725                   0.776        15.0            47.0     0.0
# 2        11561                   0.624         5.0            83.0     0.0
# 3        33241                   0.789         0.0            52.0     1.0
# 4          666                   0.767        20.0             8.0     0.0

# %%
si = SimpleImputer(strategy='mean')
new_fill_data = si.fit_transform(new_data)

# %%
new_data.columns
# Out:
# Index(['enrollee_id', 'city_development_index', 'experience', 'training_hours',
#        'target'],
#       dtype='object')

# %%
new_data = pd.DataFrame(new_fill_data,columns = new_data.columns)

# %%
new_data
# Out:
#        enrollee_id  city_development_index  experience  training_hours  target
# 0           8949.0                   0.920        20.0            36.0     1.0
# 1          29725.0                   0.776        15.0            47.0     0.0
# 2          11561.0                   0.624         5.0            83.0     0.0
# 3          33241.0                   0.789         0.0            52.0     1.0
# 4            666.0                   0.767        20.0             8.0     0.0
# ...            ...                     ...         ...             ...     ...
# 19153       7386.0                   0.878        14.0            42.0     1.0
# 19154      31398.0                   0.920        14.0            52.0     1.0
# 19155      24576.0                   0.920        20.0            44.0     0.0
# 19156       5756.0                   0.802         0.0            97.0     0.0
# 19157      23834.0                   0.855         2.0           127.0     0.0
#
# ...

# %%
new_data.isnull().sum()
# Out:
# enrollee_id               0
# city_development_index    0
# experience                0
# training_hours            0
# target                    0
# dtype: int64

# %%
new_data.columns
# Out:
# Index(['enrollee_id', 'city_development_index', 'experience', 'training_hours',
#        'target'],
#       dtype='object')

# %%
df['experience'] = new_data['experience']

# %%
df.isnull().sum()
# Out:
# enrollee_id               0
# city                      0
# city_development_index    0
# gender                    0
# relevent_experience       0
# enrolled_university       0
# education_level           0
# major_discipline          0
# experience                0
# training_hours            0
# target                    0
# dtype: int64
