# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
df = pd.read_csv('loan_data_set.csv')

# %%
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# 2             1.0         Urban           Y
# 3             1.0         Urban           Y
# 4             1.0         Urban           Y

# %%
df.fillna(method = 'bfill',inplace= True)
# Out:
# C:\Users\samay\AppData\Local\Temp\ipykernel_21004\784014395.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method = 'bfill',inplace= True)

# %%
column = df.select_dtypes(include=[int,float]).columns

# %%
Q1 = df[column].quantile(0.25)
Q2 = df[column].quantile(0.75)

# %%
IQR = Q2 - Q1

# %%
max_range = Q2 + (1.5 * IQR)

# %%
newdf = pd.DataFrame(df.select_dtypes(include=[int,float]))

# %%
plt.figure(figsize=(10,5))
sns.histplot(newdf,kde = True)
plt.show()

# %%
from sklearn.preprocessing import  StandardScaler

# %%
obj = StandardScaler()
value = obj.fit_transform(newdf)

# %%
newdf = pd.DataFrame(value,columns = column)

# %%
newdf
# Out:
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0           0.072991          -0.554487   -0.217057          0.273231
# 1          -0.134412          -0.038732   -0.217057          0.273231
# 2          -0.393747          -0.554487   -0.947774          0.273231
# 3          -0.462062           0.251980   -0.311343          0.273231
# 4           0.097728          -0.554487   -0.063843          0.273231
# ..               ...                ...         ...               ...
# 609        -0.410130          -0.554487   -0.888845          0.273231
# 610        -0.212557          -0.554487   -1.254204         -2.522836
# 611         0.437174          -0.472404    1.256161          0.273231
# 612         0.357064          -0.554487    0.478302          0.273231
# 613        -0.134412          -0.554487   -0.158129          0.273231
#
#      Credit_History
# 0          0.433152
# 1          0.433152
# 2          0.433152
# 3          0.433152
# 4          0.433152
# ..              ...
# 609        0.433152
# 610        0.433152
# 611        0.433152
# 612        0.433152
# 613       -2.308657
#
# [614 rows x 5 columns]
