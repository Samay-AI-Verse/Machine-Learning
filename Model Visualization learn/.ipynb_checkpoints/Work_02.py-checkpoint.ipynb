# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv("bottle.csv")
# Out:
# C:\Users\samay\AppData\Local\Temp\ipykernel_6652\969901055.py:4: DtypeWarning: Columns (47,73) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("bottle.csv")

# %%
# df.head() # df[["Btl_Cnt","Depthm","T_degC","Salnty"],"STheta","R_PRES"]

# %%
df = df[['Depthm', 'Salnty', 'T_degC']]

# %%
# plt.figure(figsize=(10,4))

plt.scatter(df["Salnty"],df["T_degC"])
plt.xlabel("Salnty")
plt.ylabel("T_degC")

plt.show()

# %%
df["T_degC"].corr(df["Salnty"])
# Out:
# np.float64(-0.5052659661915729)

# %%
df.dropna(inplace = True)

# %%
df.head()
# Out:
#    Depthm  Salnty  T_degC
# 0       0  33.440   10.50
# 1       8  33.440   10.46
# 2      10  33.437   10.46
# 3      19  33.420   10.45
# 4      20  33.421   10.45

# %%
# plt.scatter(df["Depthm"],df["Salnty"])

# %%
from sklearn.linear_model import LinearRegression

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
X = df[["Depthm","Salnty"]]

# %%
Y = df["T_degC"]

# %%
# df["T_degC"].corr(df["Salnty"])

# %%
x_train,x_test,y_train,y_test = train_test_split(X,Y, random_state=42,test_size=0.2)

# %%
model = LinearRegression()

# %%
model.fit(X,Y)
# Out:
# LinearRegression()

# %%
model.score(x_test,y_test)
# Out:
# 0.4787089653612774

# %%
plt.boxplot(df["T_degC"])
plt.show()

# %%
from sklearn.linear_model import  LogisticRegression

# %%
model2 = LogisticRegression()

# %%
# from sklearn.metrics import ConfusionMatrixDisplay,confusion_matrix

# %%
# y_predict = model.predict(x_test)

# %%
# y_predict

# %%
# cm = confusion_matrix(y_test,y_predict)

# %%
# model2.fit(X,Y)

# %%
from sklearn.ensemble import  RandomForestRegressor

# %%
model3 = RandomForestRegressor(n_estimators=100)

# %%
model3.fit(X,Y)
