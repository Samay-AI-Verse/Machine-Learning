# %%
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df = pd.read_csv("D:\Data Science\Model all\Machine Learing\Practice_datasets\data_science_job.csv")

# %%
df.head()
# Out:
#    enrollee_id      city  city_development_index gender  \
# 0         8949  city_103                   0.920   Male
# 1        29725   city_40                   0.776   Male
# 2        11561   city_21                   0.624    NaN
# 3        33241  city_115                   0.789    NaN
# 4          666  city_162                   0.767   Male
#
#        relevent_experience enrolled_university education_level  \
# 0  Has relevent experience       no_enrollment        Graduate
# 1   No relevent experience       no_enrollment        Graduate
# 2   No relevent experience    Full time course        Graduate
# 3   No relevent experience                 NaN        Graduate
# 4  Has relevent experience       no_enrollment         Masters
#
#   major_discipline  experience company_size    company_type  training_hours  \
# 0             STEM        20.0          NaN             NaN            36.0
# 1             STEM        15.0        50-99         Pvt Ltd            47.0
# ...

# %%
nullValue = df.isnull().sum().sum()

# %%
df.size / nullValue
# Out:
# np.float64(11.554349338900487)

# %%
df.drop(["company_size","company_type","training_hours", "major_discipline" ,"enrolled_university"],axis = 1,inplace = True)

# %%
df.isnull().sum()
# Out:
# enrollee_id                  0
# city                         0
# city_development_index     479
# gender                    4508
# relevent_experience          0
# education_level            460
# experience                  65
# target                       0
# dtype: int64

# %%
df["gender"]
# Out:
# 0        Male
# 1        Male
# 2         NaN
# 3         NaN
# 4        Male
#          ...
# 19153    Male
# 19154    Male
# 19155    Male
# 19156    Male
# 19157     NaN
# Name: gender, Length: 19158, dtype: object

# %%
df["gender"].fillna("NA", inplace = True)

# %%
df.dropna(inplace = True)

# %%
df.head()
# Out:
#    enrollee_id      city  city_development_index gender  \
# 0         8949  city_103                   0.920   Male
# 1        29725   city_40                   0.776   Male
# 2        11561   city_21                   0.624     NA
# 3        33241  city_115                   0.789     NA
# 4          666  city_162                   0.767   Male
#
#        relevent_experience education_level  experience  target
# 0  Has relevent experience        Graduate        20.0     1.0
# 1   No relevent experience        Graduate        15.0     0.0
# 2   No relevent experience        Graduate         5.0     0.0
# 3   No relevent experience        Graduate         0.0     1.0
# 4  Has relevent experience         Masters        20.0     0.0

# %%
newdf = df[["city_development_index", "gender","education_level","experience",'target']]

# %%
df['target'] = df['target'].astype(int)

# %%
def data(val):
    # Return 1 if the value is 0, else 0
    list = []
    list2 = []
    if val == 0:
        list.append(val)
    else:
        list2.append(val)
    
    return

# %%
# [print(x) for x in [1,2,3,4]]

# %%
newdf
# Out:
#        city_development_index gender education_level  experience  target
# 0                       0.920   Male        Graduate        20.0     1.0
# 1                       0.776   Male        Graduate        15.0     0.0
# 2                       0.624     NA        Graduate         5.0     0.0
# 3                       0.789     NA        Graduate         0.0     1.0
# 4                       0.767   Male         Masters        20.0     0.0
# ...                       ...    ...             ...         ...     ...
# 19153                   0.878   Male        Graduate        14.0     1.0
# 19154                   0.920   Male        Graduate        14.0     1.0
# 19155                   0.920   Male        Graduate        20.0     0.0
# 19156                   0.802   Male     High School         0.0     0.0
# 19157                   0.855     NA  Primary School         2.0     0.0
#
# [18173 rows x 5 columns]

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
obj = OneHotEncoder()

# %%
obj.fit(newdf[['gender']])
# Out:
# OneHotEncoder()

# %%
obj.transform(newdf[['gender']])
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 18173 stored elements and shape (18173, 4)>

# %%
from sklearn.preprocessing import LabelEncoder

# %%
obj = LabelEncoder()

# %%
obj.fit(newdf['gender'])
# Out:
# LabelEncoder()

# %%
value = obj.transform(newdf['gender'])

# %%
newdf['gender'] = value
# Out:
# C:\Users\samay\AppData\Local\Temp\ipykernel_4280\3732433977.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   newdf['gender'] = value

# %%
newdf.head()
# Out:
#    city_development_index  gender  education_level  experience  target
# 0                   0.920       1                0        20.0     1.0
# 1                   0.776       1                0        15.0     0.0
# 2                   0.624       2                0         5.0     0.0
# 3                   0.789       2                0         0.0     1.0
# 4                   0.767       1                2        20.0     0.0

# %%
from sklearn.linear_model import LinearRegression

# %%
from sklearn.model_selection import train_test_split

# %%
X = newdf.iloc[:,:-1]

# %%
Y = newdf.iloc[:,-1:]

# %%
x_train,x_test,y_train,y_test = train_test_split(X,Y, test_size = 0.2)

# %%
newdf.head()
# Out:
#    city_development_index  gender  education_level  experience  target
# 0                   0.920       1                0        20.0     1.0
# 1                   0.776       1                0        15.0     0.0
# 2                   0.624       2                0         5.0     0.0
# 3                   0.789       2                0         0.0     1.0
# 4                   0.767       1                2        20.0     0.0

# %%
sns.histplot(newdf["city_development_index"], kde=True)
# Out:
# <Axes: xlabel='city_development_index', ylabel='Count'>

# %%
sns.boxplot(x=df["city_development_index"])
plt.title("My title")
plt.show()

# %%
sns.scatterplot(data=df, x = "city_development_index",y="experience",hue="target")
plt.title('Relationship: CDI vs Experience by Target')
plt.show()

# %%
plt.figure(figsize=(10, 6))
correlation = newdf.corr()
sns.heatmap(correlation,annot=True, cmap='coolwarm', fmt=".2f")
# Out:
# <Axes: >
