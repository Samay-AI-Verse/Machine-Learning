# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df = pd.read_csv('C:\Data Science\Model all\Machine Learing\Classification\Logistic regreesion\startup_data.csv')
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# C:\Users\siddh\AppData\Local\Temp\ipykernel_13324\872810161.py:1: SyntaxWarning: invalid escape sequence '\D'
#   df = pd.read_csv('C:\Data Science\Model all\Machine Learing\Classification\Logistic regreesion\startup_data.csv')

# %%
df.head()
# Out:
#   Startup Name Industry  Funding Rounds  Funding Amount (M USD)  \
# 0    Startup_1      IoT               1                  101.09
# 1    Startup_2   EdTech               1                  247.62
# 2    Startup_3   EdTech               1                  109.24
# 3    Startup_4   Gaming               5                   10.75
# 4    Startup_5      IoT               4                  249.28
#
#    Valuation (M USD)  Revenue (M USD)  Employees  Market Share (%)  \
# 0             844.75            67.87       1468              5.20
# 1            3310.83            75.65       3280              8.10
# 2            1059.37            84.21       4933              2.61
# 3             101.90            47.08       1059              2.53
# 4             850.11            50.25       1905              4.09
#
#    Profitable  Year Founded         Region Exit Status
# 0           0          2006         Europe     Private
# 1           1          2003  South America     Private
# ...

# %%
df['Profitable'].value_counts()
# Out:
# Profitable
# 0    284
# 1    216
# Name: count, dtype: int64

# %% [markdown]
# # The Community has more losess in the new startup

# %%
plt.Figure(figsize=(6,4))
plt.bar(['Not Profitable', 'Profitable'], df['Profitable'].value_counts())
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df['Industry'].unique()
# Out:
# array(['IoT', 'EdTech', 'Gaming', 'AI', 'HealthTech', 'FinTech',
#        'Cybersecurity', 'E-Commerce'], dtype=object)

# %% [markdown]
# # The Industry Analysis
# E-Comerce Startup is more profitable
# Cyber-security has the less profit margin

# %%
df.groupby('Industry')['Profitable'].sum().plot(kind = 'bar')
plt.show()

# %%
df.head()
# Out:
#   Startup Name Industry  Funding Rounds  Funding Amount (M USD)  \
# 0    Startup_1      IoT               1                  101.09
# 1    Startup_2   EdTech               1                  247.62
# 2    Startup_3   EdTech               1                  109.24
# 3    Startup_4   Gaming               5                   10.75
# 4    Startup_5      IoT               4                  249.28
#
#    Valuation (M USD)  Revenue (M USD)  Employees  Market Share (%)  \
# 0             844.75            67.87       1468              5.20
# 1            3310.83            75.65       3280              8.10
# 2            1059.37            84.21       4933              2.61
# 3             101.90            47.08       1059              2.53
# 4             850.11            50.25       1905              4.09
#
#    Profitable  Year Founded         Region Exit Status
# 0           0          2006         Europe     Private
# 1           1          2003  South America     Private
# ...

# %% [markdown]
# # Wich industry has more Revenue

# %%
df.groupby('Industry')['Revenue (M USD)'].mean().plot(kind = 'bar')
# Out:
# <Axes: xlabel='Industry'>

# %%
newdf = df.groupby('Industry')[['Funding Amount (M USD)', 'Revenue (M USD)']].sum()

# %%
newdf.reset_index(inplace = True)

# %%
newdf['Revenue-to-Funding'] = newdf['Revenue (M USD)'] / newdf['Funding Amount (M USD)']

# %%
newdf
# Out:
#         Industry  Funding Amount (M USD)  Revenue (M USD)  Revenue-to-Funding
# 0             AI                 8577.05          2881.92            0.336004
# 1  Cybersecurity                 7972.31          2977.40            0.373468
# 2     E-Commerce                11524.31          3589.89            0.311506
# 3         EdTech                11212.13          3449.48            0.307656
# 4        FinTech                11646.43          3513.41            0.301673
# 5         Gaming                10735.26          3189.84            0.297137
# 6     HealthTech                 6611.42          2520.83            0.381284
# 7            IoT                 8049.47          2538.10            0.315313

# %%
df.head()
# Out:
#   Startup Name Industry  Funding Rounds  Funding Amount (M USD)  \
# 0    Startup_1      IoT               1                  101.09
# 1    Startup_2   EdTech               1                  247.62
# 2    Startup_3   EdTech               1                  109.24
# 3    Startup_4   Gaming               5                   10.75
# 4    Startup_5      IoT               4                  249.28
#
#    Valuation (M USD)  Revenue (M USD)  Employees  Market Share (%)  \
# 0             844.75            67.87       1468              5.20
# 1            3310.83            75.65       3280              8.10
# 2            1059.37            84.21       4933              2.61
# 3             101.90            47.08       1059              2.53
# 4             850.11            50.25       1905              4.09
#
#    Profitable  Year Founded         Region Exit Status
# 0           0          2006         Europe     Private
# 1           1          2003  South America     Private
# ...

# %%
grouped_data = df.groupby(['Year Founded', 'Industry'])['Revenue (M USD)'].sum().reset_index()

# %%
plt.figure(figsize=(12, 6))
sns.lineplot(data=grouped_data, x='Year Founded', y='Revenue (M USD)', hue='Industry', marker="o")

plt.title('Industry-wise Revenue over Years')
plt.xlabel('Year Founded')
plt.ylabel('Total Revenue (M USD)')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
df.head()
# Out:
#   Startup Name Industry  Funding Rounds  Funding Amount (M USD)  \
# 0    Startup_1      IoT               1                  101.09
# 1    Startup_2   EdTech               1                  247.62
# 2    Startup_3   EdTech               1                  109.24
# 3    Startup_4   Gaming               5                   10.75
# 4    Startup_5      IoT               4                  249.28
#
#    Valuation (M USD)  Revenue (M USD)  Employees  Market Share (%)  \
# 0             844.75            67.87       1468              5.20
# 1            3310.83            75.65       3280              8.10
# 2            1059.37            84.21       4933              2.61
# 3             101.90            47.08       1059              2.53
# 4             850.11            50.25       1905              4.09
#
#    Profitable  Year Founded         Region Exit Status
# 0           0          2006         Europe     Private
# 1           1          2003  South America     Private
# ...

# %%
df.groupby('Exit Status')['Profitable'].sum().plot(kind = 'bar')
# Out:
# <Axes: xlabel='Exit Status'>

# %%
x = df.groupby('Region')[['Profitable','Revenue (M USD)','Funding Amount (M USD)']].sum().reset_index()

# %%
x['New Values'] = (x['Revenue (M USD)'] / x['Funding Amount (M USD)'] ) * 100

# %%
x
# Out:
#           Region  Profitable  Revenue (M USD)  Funding Amount (M USD)  \
# 0           Asia          49          4972.65                16146.33
# 1      Australia          52          5088.53                15846.84
# 2         Europe          47          5466.43                14501.24
# 3  North America          37          5030.69                15559.09
# 4  South America          31          4102.57                14274.88
#
#    New Values
# 0   30.797401
# 1   32.110692
# 2   37.696294
# 3   32.332804
# 4   28.739786

# %%
df.head()
# Out:
#   Startup Name Industry  Funding Rounds  Funding Amount (M USD)  \
# 0    Startup_1      IoT               1                  101.09
# 1    Startup_2   EdTech               1                  247.62
# 2    Startup_3   EdTech               1                  109.24
# 3    Startup_4   Gaming               5                   10.75
# 4    Startup_5      IoT               4                  249.28
#
#    Valuation (M USD)  Revenue (M USD)  Employees  Market Share (%)  \
# 0             844.75            67.87       1468              5.20
# 1            3310.83            75.65       3280              8.10
# 2            1059.37            84.21       4933              2.61
# 3             101.90            47.08       1059              2.53
# 4             850.11            50.25       1905              4.09
#
#    Profitable  Year Founded         Region Exit Status
# 0           0          2006         Europe     Private
# 1           1          2003  South America     Private
# ...

# %%
x = ['Industry', 'Funding Amount (M USD)', 'Revenue (M USD)', 'Profitable']

# %%
modeldf = df[x]

# %%
modeldf.head()
# Out:
#   Industry  Funding Amount (M USD)  Revenue (M USD)  Profitable
# 0      IoT                  101.09            67.87           0
# 1   EdTech                  247.62            75.65           1
# 2   EdTech                  109.24            84.21           1
# 3   Gaming                   10.75            47.08           0
# 4      IoT                  249.28            50.25           0

# %%
sns.pairplot(data = modeldf)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
obj = LabelEncoder()
modeldf['Industry encoded'] = obj.fit_transform(modeldf['Industry'])
# Out:
# C:\Users\siddh\AppData\Local\Temp\ipykernel_13324\2393405554.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   modeldf['Industry encoded'] = obj.fit_transform(modeldf['Industry'])

# %%
from sklearn.model_selection import train_test_split

# %%
X = modeldf.iloc[:,1:]

# %%
X.drop('Profitable', axis = 1, inplace = True)

# %%
Y = modeldf['Profitable']

# %%
x_train,x_test,y_train,y_test = train_test_split(X,Y,test_size=0.2,random_state=42)

# %%
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
model.score(x_test,y_test) * 100
# Out:
# 60.0

# %%
linear = modeldf[['Funding Amount (M USD)','Revenue (M USD)']]

# %%
linear.head()
# Out:
#    Funding Amount (M USD)  Revenue (M USD)
# 0                  101.09            67.87
# 1                  247.62            75.65
# 2                  109.24            84.21
# 3                   10.75            47.08
# 4                  249.28            50.25

# %%
#  y = mx + b

# %%
SX = linear['Funding Amount (M USD)'].sum()

# %%
SY = linear['Revenue (M USD)'].sum()

# %%
SXY = linear['Funding Amount (M USD)'] * linear['Revenue (M USD)']

# %%
SXY = SXY.sum()

# %%
SXP = np.square(linear['Funding Amount (M USD)']).sum()

# %%
M = (500 * SXY - SX * SY) / ( 500*SXP - (SX) **  2)

# %%
b = (SY - M * SX ) / 500

# %%
b
# Out:
# np.float64(47.61552060955987)

# %%
y = M * 101.09 + b

# %%
y
# Out:
# np.float64(48.745386841357224)

# %%
n = len(linear['Funding Amount (M USD)'])
SX = np.sum(linear['Funding Amount (M USD)'])
SY = np.sum(linear['Revenue (M USD)'])
SXY = np.sum(linear['Funding Amount (M USD)'] * linear['Revenue (M USD)'])
SXP = np.sum(linear['Funding Amount (M USD)'] ** 2)

# Calculate slope (m) and intercept (b)
m = (n * SXY - SX * SY) / (n * SXP - SX ** 2)
b = (SY - m * SX) / n

print(f"Slope (m): {m}")
print(f"Intercept (b): {b}")
# Out:
# Slope (m): 0.011176834818452391
# Intercept (b): 47.61552060955987

# %%
Y = m * 101.09 + b

# %%
Y
# Out:
# np.float64(48.745386841357224)
