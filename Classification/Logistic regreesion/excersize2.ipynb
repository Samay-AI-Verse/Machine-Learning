# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df = pd.read_csv('C:\Data Science\Model all\Machine Learing\Classification\Logistic regreesion\HR_comma_sep.csv')
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# C:\Users\siddh\AppData\Local\Temp\ipykernel_9248\2498065458.py:1: SyntaxWarning: invalid escape sequence '\D'
#   df = pd.read_csv('C:\Data Science\Model all\Machine Learing\Classification\Logistic regreesion\HR_comma_sep.csv')

# %%
df.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  left  promotion_last_5years Department  \
# 0                   3              0     1                      0      sales
# 1                   6              0     1                      0      sales
# 2                   4              0     1                      0      sales
# 3                   5              0     1                      0      sales
# 4                   3              0     1                      0      sales
#
#    salary
# 0     low
# 1  medium
# ...

# %%
list = ['satisfaction_level', 'average_montly_hours', 'promotion_last_5years','salary','left']

# %%
newdf = df[list]

# %%
import seaborn as sns
sns.boxplot(x='left', y='satisfaction_level', data=df)
# Out:
# <Axes: xlabel='left', ylabel='satisfaction_level'>

# %%
df.groupby('left')['satisfaction_level'].mean()
# Out:
# left
# 0    0.666810
# 1    0.440098
# Name: satisfaction_level, dtype: float64

# %%
df.groupby('promotion_last_5years')['left'].sum()
# Out:
# promotion_last_5years
# 0    3552
# 1      19
# Name: left, dtype: int64

# %%
df['promotion_last_5years'].value_counts()
# Out:
# promotion_last_5years
# 0    14680
# 1      319
# Name: count, dtype: int64

# %%
df['Department'].value_counts(),
# Out:
# Department
# sales          4140
# technical      2720
# support        2229
# IT             1227
# product_mng     902
# marketing       858
# RandD           787
# accounting      767
# hr              739
# management      630
# Name: count, dtype: int64

# %%
plt.figure(figsize = (8,5))
sns.countplot(data = df, x = 'salary', hue = 'left')
# Out:
# <Axes: xlabel='salary', ylabel='count'>

# %%
plt.figure(figsize = (8,5))
sns.countplot(data = df, x = 'Department', hue = 'left')
# Out:
# <Axes: xlabel='Department', ylabel='count'>

# %%
left = df['left'] == 1

# %%
left.shape
# Out:
# (14999,)

# %%
df.size / left.shape[0]
# Out:
# 10.0

# %%
df.groupby('left')['Department']

# %%
plt.figure(figsize = (6,4))

plt.bar(['Left'])

plt.show()

# %%
df[df['left'] == 1].shape[0],df[df['left'] == 0].shape[0]
# Out:
# (3571, 11428)

# %%
df['left'].value_counts().plot(kind = 'bar')
# Out:
# <Axes: xlabel='left'>

# %%
sns.pairplot(data = newdf)

# %%
newdf.head()
# Out:
#    satisfaction_level  average_montly_hours  promotion_last_5years  salary  \
# 0                0.38                   157                      0     low
# 1                0.80                   262                      0  medium
# 2                0.11                   272                      0  medium
# 3                0.72                   223                      0     low
# 4                0.37                   159                      0     low
#
#    left
# 0     1
# 1     1
# 2     1
# 3     1
# 4     1

# %%
from sklearn.preprocessing import LabelEncoder

# %%
obj = LabelEncoder()

# %%
newdf['Sallary Encoding'] = obj.fit_transform(newdf['salary'])
# Out:
# C:\Users\siddh\AppData\Local\Temp\ipykernel_9248\545886643.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   newdf['Sallary Encoding'] = obj.fit_transform(newdf['salary'])

# %%
X = newdf.drop(['left','salary'], axis = 1)

# %%
X
# Out:
#        satisfaction_level  average_montly_hours  promotion_last_5years
# 0                    0.38                   157                      0
# 1                    0.80                   262                      0
# 2                    0.11                   272                      0
# 3                    0.72                   223                      0
# 4                    0.37                   159                      0
# ...                   ...                   ...                    ...
# 14994                0.40                   151                      0
# 14995                0.37                   160                      0
# 14996                0.37                   143                      0
# 14997                0.11                   280                      0
# 14998                0.37                   158                      0
#
# [14999 rows x 3 columns]

# %%
Y = newdf['left']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %%
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression()

# %%
model.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
model.score(x_test, y_test)
# Out:
# 0.757

# %%
model.predict([[0.55,	157,	1]])
# Out:
# C:\Users\siddh\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([0])

# %%
df2 = pd.read_csv('C:\Data Science\Model all\Machine Learing\Classification\Logistic regreesion\startup_data.csv')
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# C:\Users\siddh\AppData\Local\Temp\ipykernel_9248\477526770.py:1: SyntaxWarning: invalid escape sequence '\D'
#   df2 = pd.read_csv('C:\Data Science\Model all\Machine Learing\Classification\Logistic regreesion\startup_data.csv')

# %%
df2.head()
# Out:
#   Startup Name Industry  Funding Rounds  Funding Amount (M USD)  \
# 0    Startup_1      IoT               1                  101.09
# 1    Startup_2   EdTech               1                  247.62
# 2    Startup_3   EdTech               1                  109.24
# 3    Startup_4   Gaming               5                   10.75
# 4    Startup_5      IoT               4                  249.28
#
#    Valuation (M USD)  Revenue (M USD)  Employees  Market Share (%)  \
# 0             844.75            67.87       1468              5.20
# 1            3310.83            75.65       3280              8.10
# 2            1059.37            84.21       4933              2.61
# 3             101.90            47.08       1059              2.53
# 4             850.11            50.25       1905              4.09
#
#    Profitable  Year Founded         Region Exit Status
# 0           0          2006         Europe     Private
# 1           1          2003  South America     Private
# ...
