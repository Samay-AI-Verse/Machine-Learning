# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df = pd.read_csv('C:\Data Science\Model all\Machine Learing\Classification\Logistic regreesion\HR_comma_sep.csv')
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# C:\Users\siddh\AppData\Local\Temp\ipykernel_3848\2498065458.py:1: SyntaxWarning: invalid escape sequence '\D'
#   df = pd.read_csv('C:\Data Science\Model all\Machine Learing\Classification\Logistic regreesion\HR_comma_sep.csv')

# %%
df.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  left  promotion_last_5years Department  \
# 0                   3              0     1                      0      sales
# 1                   6              0     1                      0      sales
# 2                   4              0     1                      0      sales
# 3                   5              0     1                      0      sales
# 4                   3              0     1                      0      sales
#
#    salary
# 0     low
# 1  medium
# ...

# %%
df['Department'].unique(),df['salary'].unique()
# Out:
# (array(['sales', 'accounting', 'hr', 'technical', 'support', 'management',
#         'IT', 'product_mng', 'marketing', 'RandD'], dtype=object),
#  array(['low', 'medium', 'high'], dtype=object))

# %%
from sklearn.preprocessing import LabelEncoder

# %%
obj = LabelEncoder()

# %%
df['salary'] = obj. fit_transform(df['salary'])

# %%
df['Department'] = obj.fit_transform(df['Department'])

# %%
df.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  left  promotion_last_5years  Department  \
# 0                   3              0     1                      0           7
# 1                   6              0     1                      0           7
# 2                   4              0     1                      0           7
# 3                   5              0     1                      0           7
# 4                   3              0     1                      0           7
#
#    salary
# 0       1
# 1       2
# ...

# %%
retail = df.left == 0

# %%
retail.shape
# Out:
# (14999,)

# %%
df.groupby('left').mean()
# Out:
#       satisfaction_level  last_evaluation  number_project  \
# left
# 0               0.666810         0.715473        3.786664
# 1               0.440098         0.718113        3.855503
#
#       average_montly_hours  time_spend_company  Work_accident  \
# left
# 0               199.060203            3.380032       0.175009
# 1               207.419210            3.876505       0.047326
#
#       promotion_last_5years  Department    salary
# left
# 0                  0.026251    5.819041  1.347742
# 1                  0.005321    6.035284  1.345842

# %%
df.groupby('left')

# %%
sns.countplot(x = 'salary', hue = 'left', data = df)
# Out:
# <Axes: xlabel='salary', ylabel='count'>

# %%
pd.crosstab(df.salary,df.left).plot(kind = 'bar')
# Out:
# <Axes: xlabel='salary'>

# %%
sns.countplot(x  = 'Department', hue = 'left', data = df)
# Out:
# <Axes: xlabel='Department', ylabel='count'>

# %%
pd.crosstab(df.Department,df.left).plot(kind = 'bar')
# Out:
# <Axes: xlabel='Department'>

# %%
x = df.drop('left', axis = 1)

# %%
y = df.left

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 42)

# %%
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression()

# %%
model.fit(x_train,y_train)
# Out:
# c:\Users\siddh\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
model.score(x_test,y_test)
# Out:
# 0.7573333333333333

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_scaled = scaler.fit_transform(x)

# %%
df.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  left  promotion_last_5years  Department  \
# 0                   3              0     1                      0           7
# 1                   6              0     1                      0           7
# 2                   4              0     1                      0           7
# 3                   5              0     1                      0           7
# 4                   3              0     1                      0           7
#
#    salary
# 0       1
# 1       2
# ...

# %%
list= ['satisfaction_level',	'average_montly_hours',	'promotion_last_5years','salary']

# %%
x = df[list]

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 42)

# %%
model2 = LogisticRegression()

# %%
model2.fit(x,y)
# Out:
# LogisticRegression()

# %%
model2.score(x_test,y_test)
# Out:
# 0.7586666666666667

# %%
model2.predict(x_test)
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)
