# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('placement.csv')

# %%
data.head()
# Out:
#    Unnamed: 0  cgpa     iq  placement
# 0           0   6.8  123.0          1
# 1           1   5.9  106.0          0
# 2           2   5.3  121.0          0
# 3           3   7.4  132.0          1
# 4           4   5.8  142.0          0

# %%
# x = cgpa
# y = package

# %%
x = data[['cgpa']]
y = data['iq']

# %%
plt.figure(figsize = (6,4))

sns.scatterplot(x = 'cgpa',y = 'iq',data = data)

plt.show()

# %%
# Y = MX + C

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=45)

# %%
from sklearn.linear_model import LinearRegression

# %%
objLinear = LinearRegression()

# %%
objLinear.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
objLinear.score(x_test,y_test)*100
# Out:
# -11.519361559127095

# %%
objLinear.predict([[6.89]])
# Out:
# C:\Users\siddh\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([117.42170148])

# %%
plt.figure(figsize = (6,4))

sns.scatterplot(x = 'cgpa',y = 'iq',data = data)
plt.plot(x,objLinear.predict(x),c= 'k')
plt.show()
