# %%
import pandas as pd 
import matplotlib.pyplot as plt 
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv(r'Iris.csv')

# %%
df = df.iloc[:,1:]

# %%
df['Species'].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
sns.pairplot(data = df)

# %%
df.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %%
from sklearn.preprocessing import LabelEncoder

# %%
la = LabelEncoder()

# %%
df['Species_data'] = la.fit_transform(df['Species'])

# %%
df.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species  \
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa
#
#    Species_data
# 0             0
# 1             0
# 2             0
# 3             0
# 4             0

# %%
df.columns
# Out:
# Index(['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species', 'Species_data'],
#       dtype='object')

# %%
newdf = df[['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
        'Species_data']]

# %%
newdf.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species_data
# 0            5.1           3.5            1.4           0.2             0
# 1            4.9           3.0            1.4           0.2             0
# 2            4.7           3.2            1.3           0.2             0
# 3            4.6           3.1            1.5           0.2             0
# 4            5.0           3.6            1.4           0.2             0

# %%
x = newdf.iloc[:,:-1]
y = newdf['Species_data']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.1,random_state=42)

# %%
from sklearn.linear_model import LinearRegression

# %%
li = LinearRegression()

# %%
li.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
li.score(x_test,y_test) *100
# Out:
# 92.60875950900544

# %%
data = li.predict([[5.1	,3.5	,1.4	,0.2]])
# Out:
# C:\Users\siddh\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
data
# Out:
# array([-0.09007523])

# %%
newdf.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species_data
# 0            5.1           3.5            1.4           0.2             0
# 1            4.9           3.0            1.4           0.2             0
# 2            4.7           3.2            1.3           0.2             0
# 3            4.6           3.1            1.5           0.2             0
# 4            5.0           3.6            1.4           0.2             0

# %%
sns.pairplot(data = newdf,hue='Species_data')
