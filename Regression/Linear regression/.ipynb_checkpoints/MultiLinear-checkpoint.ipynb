# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
data = pd.read_csv('Student_Performance.csv')

# %%
data.head()
# Out:
#    Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 0              7               99                        Yes            9
# 1              4               82                         No            4
# 2              8               51                        Yes            7
# 3              5               52                        Yes            5
# 4              7               75                         No            8
#
#    Sample Question Papers Practiced  Performance Index
# 0                                 1               91.0
# 1                                 2               65.0
# 2                                 2               45.0
# 3                                 2               36.0
# 4                                 5               66.0

# %%
data = data[['Hours Studied','Sample Question Papers Practiced','Previous Scores']]

# %%
data.rename(columns = {'Sample Question Papers Practiced':'Paper Practices'},inplace = True)

# %%
from sklearn.model_selection import train_test_split

# %%
x = data[['Hours Studied']]
y = data[['Previous Scores']]

# %%
plt.figure(figsize = (8,4))
plt.subplot(1,2,1)
sns.scatterplot(x = 'Hours Studied',y = 'Previous Scores',data = data)
# Out:
# <Axes: xlabel='Hours Studied', ylabel='Previous Scores'>

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.linear_model import LinearRegression

# %%
obj = LinearRegression()

# %%
obj.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
obj.score(x,y)
# Out:
# 0.0001273046873505601

# %%
sns.pairplot(data = data)
